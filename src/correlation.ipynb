# %%
# install.packages('visNetwork')
# install.packages('igraph')
library(visNetwork)
require("igraph")
# Out:
# Loading required package: igraph
#
# Attaching package: ‘igraph’
#
# The following object is masked _by_ ‘.GlobalEnv’:
#
#     normalize
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
normalize <- function( x){
  return ((x - min(x))/ (max( x) - min (x)))
}

# %%
data_x <- read.csv(file = '../data/v1/demo_caries_x.csv')
data_y <- read.csv(file = '../data/v1/demo_caries_y.csv')
data_c <- cbind(data_x, data_y)

# %%
head(data_c)
# Out:
#   ID RIDAGEYR     RIDRETH1   RIDRETH3   RIDEXMON   RIDEXAGM   DMQMILIZ
# 1 1   1.103065040 -0.1179234 -0.2249165 -1.0220620  1.2553408  0.37097517
# 2 2   1.817110605 -0.1179234 -0.2249165  0.9781387  1.3019696 -4.63598015
# 3 3   1.539426219 -0.1179234 -0.2249165  0.9781387 -0.2750107  0.37097517
# 4 4  -0.007672505 -0.1179234 -0.2249165  0.9781387 -0.2206297  0.37097517
# 5 5   1.975787397 -0.1179234 -0.2249165 -1.0220620  1.5685187  0.37097517
# 6 6  -0.642379674  0.6577506  0.3771208 -1.0220620  0.3968447  0.09495086
#   DMDBORN4   DMDCITZN   DMDEDUC3    ... DMDHRMAR   DMDHSEDU     WTINT2YR
# 1 -0.4557345 -0.2583009  0.73309904 ... -0.2703160 -2.660908870 -0.09529293
# 2 -0.4557345 -0.2583009  0.71019259 ... -0.2703160 -0.661851200  1.36898488
# 3 -0.4557345 -0.2583009 -0.09338151 ... -0.1233476 -0.001640329  0.35537625
# 4 -0.4557345 -0.2583009 -0.05132311 ...  0.3175575  0.097165607  2.77941609
# 5 -0.4557345 -0.2583009  1.05528088 ... -0.2703160  1.337206470  0.92243056
# ...

# %%
write.csv(data_c, file = "../data/v1/demo_caries.csv")

# %%
cor(data_c,method = "p")
# Out:
#          ID            RIDAGEYR      RIDRETH1     RIDRETH3     RIDEXMON
# ID        1.000000e+00  0.0195680572  0.012629142  0.011516211 -1.125987e-05
# RIDAGEYR  1.956806e-02  1.0000000000  0.002049833 -0.021862379  1.000950e-02
# RIDRETH1  1.262914e-02  0.0020498333  1.000000000  0.967406536  4.837120e-03
# RIDRETH3  1.151621e-02 -0.0218623790  0.967406536  1.000000000  1.625372e-02
# RIDEXMON -1.125987e-05  0.0100095049  0.004837120  0.016253722  1.000000e+00
# RIDEXAGM -8.307416e-03  0.3211800186  0.033367940  0.026101000 -2.053533e-02
# DMQMILIZ -2.494420e-03 -0.2224349571 -0.014552222  0.004390511 -3.616889e-02
# DMDBORN4  2.463373e-02  0.3323681815  0.011639020  0.066359033 -1.821936e-02
# DMDCITZN  2.124027e-02  0.1270873581 -0.033468503  0.005691175 -2.579709e-03
# DMDEDUC3 -2.028755e-02  0.1487192296  0.022921096  0.025375288 -9.932256e-03
# DMDEDUC2 -4.220383e-02 -0.0986301850  0.193087951  0.178157101  2.323301e-02
# ...
